# %%
# !python list_files.py
# Out:
# list_files.py
# script2_shuffle.py
# script8_PUs.py
# script4_concatenate.py
# .ipynb_checkpoints
# script1_clean.py
# script3_sse.py
# script7_processPU.py
# PUs
# 1a9x
# script5_motifs.py
# 1a9x.pdb
# superscript.py
# script6_merge.py
# Untitled.ipynb

# %%
import os
os.chdir('1a9x')

# %%
# !python list_files.py
# Out:
# nest.dat
# niche.dat
# origin.dat
# sse5_ppII.dat
# sse_ppII.dat
# beta_bulge_loop_typeI.dat
# beta_bulge_loop_typeII.dat
# beta_turn.dat
# gamma_turn.dat
# ST_motif.dat
# cellsize.dat
# schellman_loop.dat
# beta_bulges.dat
# asx_motif.dat
# st_turn.dat
# 1a9x.pdb
# list_files.py
# alpha_beta_motif.dat

# %%
os.chdir('..')

# %%
# !python list_files.py
# Out:
# list_files.py
# script2_shuffle.py
# script8_PUs.py
# script4_concatenate.py
# .ipynb_checkpoints
# script1_clean.py
# script3_sse.py
# script7_processPU.py
# PUs
# 1a9x
# script5_motifs.py
# 1a9x.pdb
# superscript.py
# script6_merge.py
# Untitled.ipynb

# %%
import script1_clean, script2_shuffle, script3_sse, script4_concatenate, script5_motifs, script6_merge, script7_processPU, script8_PUs

# %%
script1_clean.clean_pdb('1a9x.pdb')

# %%
script2_shuffle.shuffle_pdb('1a9x.pdb')

# %%
os.chdir('1a9x_2')
# !python list_files.py
os.chdir('..')
# Out:
# 1a9x_shuffled.pdb
# 1a9x.pdb
# list_files.py

# %%
script3_sse.sse('1a9x.pdb')

# %%
os.chdir('1a9x_2')
# !python list_files.py
os.chdir('..')
# Out:
# 1a9x_shuffled.pdb
# 1a9x.pdb
# list_files.py
# sse_ppII.dat
# 1a9x_1stlevel_ss.csv
# read.py

# %%
os.chdir('1a9x_2')
# !python read.py
os.chdir('..')
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# P
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# E
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# S
# S
# S
# S
# S
# S
# S
# -
# -
# -
# -
# -
# -
# -
# -
# B
# B
# B
# B
# B
# B
# B
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# B
# B
# B
# B
# B
# B
# B
# B
# B
# -
# -
# -
# -
# -
# T
# T
# T
# T
# T
# T
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# ...

# %%
script4_concatenate.concat('1a9x.pdb')

# %%
os.chdir('1a9x_2')
# !python list_files.py
os.chdir('..')
# Out:
# 1a9x_shuffled.pdb
# 1a9x.pdb
# list_files.py
# sse_ppII.dat
# 1a9x_1stlevel_ss.csv
# read.py
# motifs.dat

# %%
script5_motifs.smallmotifs('1a9x.pdb')

# %%
os.chdir('1a9x_2')
# !python list_files.py
os.chdir('..')
# Out:
# 1a9x_shuffled.pdb
# 1a9x.pdb
# list_files.py
# sse_ppII.dat
# 1a9x_1stlevel_ss.csv
# motifs.dat
# 1a9x_1stlevel_motifs.csv
# read.py

# %%
os.chdir('1a9x_2')
# !python read.py
os.chdir('..')
# Out:
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# ...

# %%
script6_merge.merge_csv('1a9x.pdb')

# %%
os.chdir('1a9x_2')
# !python list_files.py
os.chdir('..')
# Out:
# 1a9x_shuffled.pdb
# 1a9x.pdb
# list_files.py
# sse_ppII.dat
# 1a9x_1stlevel_ss.csv
# motifs.dat
# 1a9x_1stlevel_motifs.csv
# read.py
# 1a9x_1stlevel.csv

# %%
os.chdir('1a9x_2')
# !python read.py
os.chdir('..')
# Out:
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# P,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# S,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# -,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# E,other
# ...

# %%
# !python list_PUs.py
# Out:
# PUs/PUs_aLaLa/1a9x:
# total 0
# -rwxrwxrwx 1 1000 1000 172 Oct 27 21:00 1a9x.pus
#
# PUs/PUs_aLa/1a9x:
# total 0
# -rwxrwxrwx 1 1000 1000 243 Oct 27 21:00 1a9x.pus
#
# PUs:
# total 0
# -rwxrwxrwx 1 1000 1000  10 Oct 27 21:00 list_topologies
# drwxrwxrwx 1 1000 1000 512 Oct 27 21:00 PUs_aLaLa
# drwxrwxrwx 1 1000 1000 512 Oct 28 05:02 PUs_aLa

# %%
# !python read_aLa.py
# Out:
# G [6782, 6783, 6794, 6795, 6798, 6799, 6800, 6887, 6888, 6889, 6890, 6928, 6930, 6931, 6932, 6933, 6935, 6936, 6937, 6938, 6939, 6977, 6998, 6999, 7004, 7005, 7006, 7007, 7008, 7009, 7010, 7011, 7012, 7013, 7014, 7015, 7016, 7017, 7018, 7019]

# %%
script8_PUs.generate_csv_3rdlevel('1a9x.pdb')
# Out:
# writing in csv
# writing in csv2
# adding other
# DONE FIRST CSV
# DONE SECOND CSV
# done

# %%
# !python list_files.py
# Out:
# list_files.py
# script2_shuffle.py
# script4_concatenate.py
# .ipynb_checkpoints
# script1_clean.py
# script3_sse.py
# 1a9x
# script5_motifs.py
# superscript.py
# 1a9x.pdb
# __pycache__
# 1a9x_shuffled.pdb
# read.py
# script6_merge.py
# 1a9x_2
# script7_processPU.py
# PUs
# list_PUs.py
# read_list.py
# read_aLa.py
# script8_PUs.py
# 1a9x_2ndlevel_PU_2SSE.csv
# 1a9x_2ndlevel_PU_2+SSE.csv
# Untitled.ipynb

# %%
# !python read_csv.py
# Out:
# other
# aLaLa
# other
# aLaLa
# other
# aLaLa
# other
# water
# other
# water
# other
# water
# other
# water
# other
# water
# other
# water
# other
# water
# other
# water
